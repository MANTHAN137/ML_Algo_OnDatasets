# %%
import pandas as pd

# %%
iris=pd.read_csv('Datasets\\iris.csv')

# %%
iris.head().plot()
# Out:
# <AxesSubplot:>

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris[iris['petal.width']>2.4]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='sepal.length',y='petal.length',data=iris,hue='variety')
plt.show()

# %%
y=iris[['sepal.length']]

# %%
x=iris[['sepal.width']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#      sepal.width
# 129          3.0
# 104          3.0
# 54           2.8
# 141          3.1
# 30           3.1

# %%
x_test.head()
# Out:
#      sepal.width
# 39           3.4
# 96           2.9
# 45           3.0
# 147          3.0
# 22           3.6

# %%
y_train.head()
# Out:
#      sepal.length
# 129           7.2
# 104           6.5
# 54            6.5
# 141           6.9
# 30            4.8

# %%
y_test.head()
# Out:
#      sepal.length
# 39            5.1
# 96            5.7
# 45            4.8
# 147           6.5
# 22            4.6

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# [[5.7886337 ]
#  [5.88151638]
#  [5.86293985]
#  [5.86293985]
#  [5.75148062]
#  [5.90009292]
#  [5.75148062]
#  [5.77005716]
#  [5.97439907]
#  [5.86293985]
#  [5.90009292]
#  [5.6400214 ]
#  [5.84436331]
#  [5.77005716]
#  [5.91866946]
#  [5.80721023]
#  [5.95582253]
#  [5.73290409]
#  [5.86293985]
#  [5.86293985]
#  [5.7886337 ]
#  [5.88151638]
#  [5.91866946]
#  [5.7886337 ]
#  [5.86293985]
#  [5.90009292]
#  [5.86293985]
#  [5.82578677]
#  [5.71432755]
#  [5.67717447]
#  [5.91866946]
#  [5.86293985]
#  [5.82578677]
#  [5.80721023]
#  [5.88151638]
#  [5.86293985]
#  [5.7886337 ]
#  [5.7886337 ]
#  [5.86293985]
#  [5.65859794]
#  [5.84436331]
#  [5.86293985]
#  [5.95582253]
#  [5.88151638]
#  [5.91866946]]

# %%
y_test[0:10]
# Out:
#      sepal.length
# 39            5.1
# 96            5.7
# 45            4.8
# 147           6.5
# 22            4.6
# 126           6.2
# 4             5.0
# 40            5.0
# 80            5.5
# 61            5.9

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.5838788938884772

# %% [markdown]
# Model 2

# %%
y=iris[['sepal.length']]
x=iris[['sepal.width','petal.length','petal.width']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr2=LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_test)

# %%
y_pred
# Out:
# array([[5.39835329],
#        [6.67728672],
#        [6.00668804],
#        [7.11485796],
#        [5.20257234],
#        [6.28942242],
#        [6.77300808],
#        [5.74639841],
#        [6.12003671],
#        [4.91075226],
#        [5.1377408 ],
#        [5.47878862],
#        [5.20482217],
#        [5.57354649],
#        [5.71358161],
#        [5.97637396],
#        [6.28097735],
#        [6.33142146],
#        [4.92956938],
#        [4.94260557],
#        [6.12848178],
#        [5.85974708],
#        [6.12389066],
#        [6.32586685],
#        [6.78797124],
#        [4.91919733],
#        [6.63393644],
#        [6.35772016],
#        [6.11946097],
#        [4.86377435],
#        [4.85532928],
#        [5.98883441],
#        [4.65987118],
#        [4.57163141],
#        [5.39087171],
#        [4.66083467],
#        [6.47990165],
#        [5.50364464],
#        [6.35329047],
#        [5.62325343],
#        [6.29786749],
#        [5.13154557],
#        [5.9832798 ],
# ...

# %%
y_test
# Out:
#      sepal.length
# 18            5.7
# 116           6.5
# 90            5.5
# 118           7.7
# 57            4.9
# 63            6.1
# 102           7.1
# 87            6.3
# 141           6.9
# 40            5.0
# 93            5.0
# 79            5.7
# 20            5.4
# 59            5.2
# 92            5.8
# 121           5.6
# 91            6.1
# 115           6.4
# 9             4.9
# 23            5.1
# 145           6.7
# 114           5.8
# 142           5.8
# 147           6.5
# 135           7.7
# 6             4.6
# 104           6.5
# 132           6.4
# 95            5.7
# 34            4.9
# 47            4.6
# 96            5.7
# 45            4.8
# 13            4.3
# 46            5.1
# 8             4.4
# 112           6.8
# 33            5.5
# 86            6.7
# 68            6.2
# 76            6.8
# 11            4.8
# 67            5.8
# 100           6.3
# 139           6.9

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.1264433454110894

# %% [markdown]
# Covid 19 India

# %%
dataset=pd.read_csv('Datasets\\covid.csv',parse_dates=['Date'],dayfirst=False)

# %%
#keeping only required columns
dataset=dataset[['Date','State/UnionTerritory','Cured','Deaths','Confirmed']]

dataset.columns=['date','state','cured','deaths','confirmed']

# %%
print(dataset.head())
# Out:
#         date   state  cured  deaths  confirmed
# 0 2020-01-30  Kerala      0       0          1
# 1 2020-01-31  Kerala      0       0          1
# 2 2020-01-02  Kerala      0       0          2
# 3 2020-02-02  Kerala      0       0          3
# 4 2020-03-02  Kerala      0       0          3

# %%
dataset.tail()
# Out:
#           date          state  cured  deaths  confirmed
# 796 2020-09-04      Telengana     35       7        442
# 797 2020-09-04        Tripura      0       0          1
# 798 2020-09-04    Uttarakhand      5       0         35
# 799 2020-09-04  Uttar Pradesh     31       4        410
# 800 2020-09-04    West Bengal     16       5        103

# %%
today=dataset[dataset.date=='2020-09-04']

# %%
today.head()
# Out:
#           date                        state  cured  deaths  confirmed
# 770 2020-09-04               Andhra Pradesh      6       4        348
# 771 2020-09-04  Andaman and Nicobar Islands      0       0         11
# 772 2020-09-04            Arunachal Pradesh      0       0          1
# 773 2020-09-04                        Assam      0       0         28
# 774 2020-09-04                        Bihar      0       1         39

# %%
max_confirmed_case=today.sort_values(by='confirmed',ascending=False)
print(max_confirmed_case)
# Out:
#           date                        state  cured  deaths  confirmed
# 788 2020-09-04                  Maharashtra    117      72       1135
# 795 2020-09-04                   Tamil Nadu     21       8        738
# 777 2020-09-04                        Delhi     21       9        669
# 796 2020-09-04                    Telengana     35       7        442
# 799 2020-09-04                Uttar Pradesh     31       4        410
# 794 2020-09-04                    Rajasthan     21       3        383
# 770 2020-09-04               Andhra Pradesh      6       4        348
# 785 2020-09-04                       Kerala     83       2        345
# 787 2020-09-04               Madhya Pradesh      0      16        259
# 784 2020-09-04                    Karnataka     28       5        181
# 779 2020-09-04                      Gujarat     25      16        179
# 780 2020-09-04                      Haryana     29       3        169
# ...

# %%
top_5=max_confirmed_case[0:5]
print(top_5)
# Out:
#           date          state  cured  deaths  confirmed
# 788 2020-09-04    Maharashtra    117      72       1135
# 795 2020-09-04     Tamil Nadu     21       8        738
# 777 2020-09-04          Delhi     21       9        669
# 796 2020-09-04      Telengana     35       7        442
# 799 2020-09-04  Uttar Pradesh     31       4        410

# %%
sns.set(rc={'figure.figsize':(15,10)})

sns.barplot(x='state',y='confirmed',data=top_5,hue='state')
plt.show()

# %%
sns.barplot(x='state',y='deaths',data=top_5,hue='state')
plt.show()

# %%
max_cured_cases=today.sort_values(by="cured",ascending=False)
max_cured_cases
# Out:
#           date                        state  cured  deaths  confirmed
# 788 2020-09-04                  Maharashtra    117      72       1135
# 785 2020-09-04                       Kerala     83       2        345
# 796 2020-09-04                    Telengana     35       7        442
# 799 2020-09-04                Uttar Pradesh     31       4        410
# 780 2020-09-04                      Haryana     29       3        169
# 784 2020-09-04                    Karnataka     28       5        181
# 779 2020-09-04                      Gujarat     25      16        179
# 795 2020-09-04                   Tamil Nadu     21       8        738
# 794 2020-09-04                    Rajasthan     21       3        383
# 777 2020-09-04                        Delhi     21       9        669
# 800 2020-09-04                  West Bengal     16       5        103
# 786 2020-09-04                       Ladakh     10       0         14
# ...

# %%
maha=dataset[dataset.state=='Maharashtra']
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='confirmed',data=dataset,color='r')
plt.show();

# %%
maha
# Out:
#           date        state  cured  deaths  confirmed
# 76  2020-09-03  Maharashtra      0       0          2
# 91  2020-10-03  Maharashtra      0       0          5
# 97  2020-11-03  Maharashtra      0       0          2
# 120 2020-12-03  Maharashtra      0       0         11
# 133 2020-03-13  Maharashtra      0       0         14
# 146 2020-03-14  Maharashtra      0       0         14
# 153 2020-03-15  Maharashtra      0       0         32
# 167 2020-03-16  Maharashtra      0       0         32
# 182 2020-03-17  Maharashtra      0       1         39
# 197 2020-03-18  Maharashtra      0       1         42
# 215 2020-03-19  Maharashtra      0       1         47
# 235 2020-03-20  Maharashtra      0       1         52
# 257 2020-03-21  Maharashtra      0       1         63
# 280 2020-03-22  Maharashtra      0       2         67
# 303 2020-03-23  Maharashtra      0       2         74
# 326 2020-03-24  Maharashtra      0       2         89
# ...

# %%
kerala=dataset[(dataset.state=='Kerala')]
kerala
# Out:
#           date   state  cured  deaths  confirmed
# 0   2020-01-30  Kerala      0       0          1
# 1   2020-01-31  Kerala      0       0          1
# 2   2020-01-02  Kerala      0       0          2
# 3   2020-02-02  Kerala      0       0          3
# 4   2020-03-02  Kerala      0       0          3
# ..         ...     ...    ...     ...        ...
# 663 2020-05-04  Kerala     49       2        306
# 693 2020-06-04  Kerala     55       2        314
# 723 2020-07-04  Kerala     58       2        327
# 754 2020-08-04  Kerala     70       2        336
# 785 2020-09-04  Kerala     83       2        345
#
# [71 rows x 5 columns]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='confirmed',data=kerala,color='g')
plt.show()

# %%
dataset=pd.read_csv('Datasets/covid/covid_19_india.csv',parse_dates=['Date'],dayfirst=True)

# %%
dataset
# Out:
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30  6:00 PM               Kerala                       1
# 1          2 2020-01-31  6:00 PM               Kerala                       1
# 2          3 2020-02-01  6:00 PM               Kerala                       2
# 3          4 2020-02-02  6:00 PM               Kerala                       3
# 4          5 2020-02-03  6:00 PM               Kerala                       3
# ...      ...        ...      ...                  ...                     ...
# 18105  18106 2021-08-11  8:00 AM            Telangana                       -
# 18106  18107 2021-08-11  8:00 AM              Tripura                       -
# 18107  18108 2021-08-11  8:00 AM          Uttarakhand                       -
# 18108  18109 2021-08-11  8:00 AM        Uttar Pradesh                       -
# 18109  18110 2021-08-11  8:00 AM          West Bengal                       -
#
# ...

# %%
dataset=dataset[['Date','State/UnionTerritory','Cured','Deaths','Confirmed']]
dataset.columns=['date','state','cured','deaths','confirmed']

# %%
dataset.head()
# Out:
#         date   state  cured  deaths  confirmed
# 0 2020-01-30  Kerala      0       0          1
# 1 2020-01-31  Kerala      0       0          1
# 2 2020-02-01  Kerala      0       0          2
# 3 2020-02-02  Kerala      0       0          3
# 4 2020-02-03  Kerala      0       0          3

# %%
dataset.tail()
# Out:
#             date          state    cured  deaths  confirmed
# 18105 2021-08-11      Telangana   638410    3831     650353
# 18106 2021-08-11        Tripura    77811     773      80660
# 18107 2021-08-11    Uttarakhand   334650    7368     342462
# 18108 2021-08-11  Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11    West Bengal  1506532   18252    1534999

# %%
dataset=dataset[dataset.date<='2020-07-17' ]
sns.barplot(x='date',y='cured',data=dataset)
plt.show()

# %%
fulldata=dataset.copy()

# %%
dataset=dataset[dataset.date<='2020-07-17' ]

# %%
dataset
# Out:
#            date                             state  cured  deaths  confirmed
# 0    2020-01-30                            Kerala      0       0          1
# 1    2020-01-31                            Kerala      0       0          1
# 2    2020-02-01                            Kerala      0       0          2
# 3    2020-02-02                            Kerala      0       0          3
# 4    2020-02-03                            Kerala      0       0          3
# ...         ...                               ...    ...     ...        ...
# 4210 2020-07-17                           Tripura   1604       3       2283
# 4211 2020-07-17                       Uttarakhand   2995      50       3982
# 4212 2020-07-17                     Uttar Pradesh  26675    1046      43441
# 4213 2020-07-17                       West Bengal  21415    1023      36117
# 4214 2020-07-17  Cases being reassigned to states      0       0        531
#
# [4215 rows x 5 columns]

# %%
today=dataset[dataset.date=='2020-07-17']

# %%
today
# Out:
#            date                                     state   cured  deaths  \
# 4179 2020-07-17               Andaman and Nicobar Islands     133       0
# 4180 2020-07-17                            Andhra Pradesh   19393     492
# 4181 2020-07-17                         Arunachal Pradesh     153       3
# 4182 2020-07-17                                     Assam   12888      48
# 4183 2020-07-17                                     Bihar   14018     197
# 4184 2020-07-17                                Chandigarh     476      11
# 4185 2020-07-17                              Chhattisgarh    3451      21
# 4186 2020-07-17  Dadra and Nagar Haveli and Daman and Diu     371       2
# 4187 2020-07-17                                     Delhi   97693    3545
# 4188 2020-07-17                                       Goa    1817      19
# 4189 2020-07-17                                   Gujarat   32103    2089
# 4190 2020-07-17                                   Haryana   18185     322
# ...

# %%
max_confirmed_cases=today.sort_values(by='confirmed',ascending=False)

# %%
max_confirmed_cases
# Out:
#            date                                     state   cured  deaths  \
# 4198 2020-07-17                               Maharashtra  158140   11194
# 4208 2020-07-17                                Tamil Nadu  107416    2236
# 4187 2020-07-17                                     Delhi   97693    3545
# 4194 2020-07-17                                 Karnataka   19729    1032
# 4189 2020-07-17                                   Gujarat   32103    2089
# 4212 2020-07-17                             Uttar Pradesh   26675    1046
# 4209 2020-07-17                                 Telengana   27295     396
# 4180 2020-07-17                            Andhra Pradesh   19393     492
# 4213 2020-07-17                               West Bengal   21415    1023
# 4206 2020-07-17                                 Rajasthan   19970     538
# 4190 2020-07-17                                   Haryana   18185     322
# 4183 2020-07-17                                     Bihar   14018     197
# ...

# %%
top_states_comfirmed=max_confirmed_case.head()
# top_5=max_confirmed_cases[0:5]

# %%
top_states_comfirmed
# Out:
#           date          state  cured  deaths  confirmed
# 788 2020-09-04    Maharashtra    117      72       1135
# 795 2020-09-04     Tamil Nadu     21       8        738
# 777 2020-09-04          Delhi     21       9        669
# 796 2020-09-04      Telengana     35       7        442
# 799 2020-09-04  Uttar Pradesh     31       4        410

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x='state',y='confirmed',data=top_states_comfirmed,hue='state')
plt.show()

# %%
max_death_cases=today.sort_values(by='deaths',ascending=False)
top_states_casee=max_death_cases[0:5]
max_death_cases
# Out:
#            date                                     state   cured  deaths  \
# 4198 2020-07-17                               Maharashtra  158140   11194
# 4187 2020-07-17                                     Delhi   97693    3545
# 4208 2020-07-17                                Tamil Nadu  107416    2236
# 4189 2020-07-17                                   Gujarat   32103    2089
# 4212 2020-07-17                             Uttar Pradesh   26675    1046
# 4194 2020-07-17                                 Karnataka   19729    1032
# 4213 2020-07-17                               West Bengal   21415    1023
# 4197 2020-07-17                            Madhya Pradesh   14127     689
# 4206 2020-07-17                                 Rajasthan   19970     538
# 4180 2020-07-17                            Andhra Pradesh   19393     492
# 4209 2020-07-17                                 Telengana   27295     396
# 4190 2020-07-17                                   Haryana   18185     322
# ...

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x='state',y='deaths',data=top_5,hue='state')
# Out:
# <AxesSubplot:xlabel='state', ylabel='deaths'>

# %%
max_cured_cases=today.sort_values(by='cured',ascending=False)
top_state_cured=max_cured_cases[0:5]
max_cured_cases
# Out:
#            date                                     state   cured  deaths  \
# 4198 2020-07-17                               Maharashtra  158140   11194
# 4208 2020-07-17                                Tamil Nadu  107416    2236
# 4187 2020-07-17                                     Delhi   97693    3545
# 4189 2020-07-17                                   Gujarat   32103    2089
# 4209 2020-07-17                                 Telengana   27295     396
# 4212 2020-07-17                             Uttar Pradesh   26675    1046
# 4213 2020-07-17                               West Bengal   21415    1023
# 4206 2020-07-17                                 Rajasthan   19970     538
# 4194 2020-07-17                                 Karnataka   19729    1032
# 4180 2020-07-17                            Andhra Pradesh   19393     492
# 4190 2020-07-17                                   Haryana   18185     322
# 4197 2020-07-17                            Madhya Pradesh   14127     689
# ...

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(y='cured',x='state',data=top_state_cured,hue='state')
# Out:
# <AxesSubplot:xlabel='state', ylabel='cured'>

# %%
maha=dataset[dataset.state=='Maharashtra']

# %%
maha
# Out:
#            date        state   cured  deaths  confirmed
# 76   2020-03-09  Maharashtra       0       0          2
# 91   2020-03-10  Maharashtra       0       0          5
# 97   2020-03-11  Maharashtra       0       0          2
# 120  2020-03-12  Maharashtra       0       0         11
# 133  2020-03-13  Maharashtra       0       0         14
# ...         ...          ...     ...     ...        ...
# 4054 2020-07-13  Maharashtra  140325   10289     254427
# 4090 2020-07-14  Maharashtra  144507   10482     260924
# 4126 2020-07-15  Maharashtra  149007   10695     267665
# 4162 2020-07-16  Maharashtra  152613   10928     275640
# 4198 2020-07-17  Maharashtra  158140   11194     284281
#
# [131 rows x 5 columns]

# %%
fullmaha=fulldata[fulldata.state=='Maharashtra']

# %%
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x='date',y='confirmed',data=fullmaha,color='b')
# Out:
# <AxesSubplot:xlabel='date', ylabel='confirmed'>

# %%
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x='date',y='confirmed',data=maha,color='b')
# Out:
# <AxesSubplot:xlabel='date', ylabel='confirmed'>

# %%
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x='date',y='deaths',data=maha,color='b')
# Out:
# <AxesSubplot:xlabel='date', ylabel='deaths'>

# %%
kerala=dataset[dataset.state=='Kerala']
kerala
# Out:
#            date   state  cured  deaths  confirmed
# 0    2020-01-30  Kerala      0       0          1
# 1    2020-01-31  Kerala      0       0          1
# 2    2020-02-01  Kerala      0       0          2
# 3    2020-02-02  Kerala      0       0          3
# 4    2020-02-03  Kerala      0       0          3
# ...         ...     ...    ...     ...        ...
# 4051 2020-07-13  Kerala   4095      31       7873
# 4087 2020-07-14  Kerala   4257      33       8322
# 4123 2020-07-15  Kerala   4438      34       8930
# 4159 2020-07-16  Kerala   4634      35       9553
# 4195 2020-07-17  Kerala   4862      37      10275
#
# [170 rows x 5 columns]

# %%
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x='date',y='confirmed',data=kerala,color='b')
# Out:
# <AxesSubplot:xlabel='date', ylabel='confirmed'>

# %%
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x='date',y='deaths',data=kerala,color='b')
# Out:
# <AxesSubplot:xlabel='date', ylabel='deaths'>

# %%
from sklearn.model_selection import train_test_split
import datetime as dt

# %%
maha['date']=maha['date'].map(dt.datetime.toordinal)
maha.head()
# Out:
# <ipython-input-77-e5d80cc26285>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maha['date']=maha['date'].map(dt.datetime.toordinal)
#        date        state  cured  deaths  confirmed
# 76   737493  Maharashtra      0       0          2
# 91   737494  Maharashtra      0       0          5
# 97   737495  Maharashtra      0       0          2
# 120  737496  Maharashtra      0       0         11
# 133  737497  Maharashtra      0       0         14

# %%
x=maha['date']
y=maha['confirmed']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
lr=LinearRegression()

# %%
y_train
# Out:
# 2577    70013
# 1076     3323
# 91          5
# 280        67
# 1175     4669
#         ...
# 2433    59546
# 1368     8068
# 257        63
# 133        14
# 197        42
# Name: confirmed, Length: 91, dtype: int64

# %%
x_train
# Out:
# 2577    737578
# 1076    737533
# 91      737494
# 280     737506
# 1175    737536
#          ...
# 2433    737574
# 1368    737542
# 257     737505
# 133     737497
# 197     737502
# Name: date, Length: 91, dtype: int64

# %%
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
LinearRegression(copy_X=True,fit_intercept=True,n_jobs=None,normalize=False)
# Out:
# LinearRegression()

# %%
maha.tail()
# Out:
#         date        state   cured  deaths  confirmed
# 4054  737619  Maharashtra  140325   10289     254427
# 4090  737620  Maharashtra  144507   10482     260924
# 4126  737621  Maharashtra  149007   10695     267665
# 4162  737622  Maharashtra  152613   10928     275640
# 4198  737623  Maharashtra  158140   11194     284281

# %%
lr.predict(np.array([[737623]]))
# Out:
# array([[178273.02995586]])
